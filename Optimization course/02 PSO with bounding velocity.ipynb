# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class particle:
    def __init__(self, partical_name, x, v, pbest_x, pbest_obj):
        self.name = partical_name
        self.position = x
        self.velocity = v
        self.pbest_x  = pbest_x
        self.pbest_obj = pbest_obj

    def __str__(self):
        return f" partical: {self.name}, position: {self.position}, velocity: {self.velocity}, pbest_x: {self.pbest_x}, pbest_obj: {self.pbest_obj}"

class swarm:
    def __init__(self, swarm_name, gbest_x, gbest_obj):
        self.swarm_name = swarm_name
        self.gbest_x = gbest_x
        self.gbest_obj = gbest_obj
        self.particles = []

    def add_particles(self, particle):
        self.particles.append(particle)

    def display_particles(self):
        print(f"particles in {self.swarm_name}: gbest_x= {self.gbest_x}, gbest_obj= {self.gbest_obj}")
        for particle in self.particles:
            print(particle)

# %%
nVar = 2
ub = np.array([7,7])
lb = np.array([2,2])

w_max = 0.9
w_min = 0.2
c1 =2
c2 =2
n_particals = 5

iter = 10

v_max = ( ub - lb ) *(0.2)
v_min = -v_max

def objective_function(x):
    length = x[0]
    width = x[1]
    weight = 1*(width*length)
    return weight
    # z = np.sum(np.square(x))
    # return z


swarm_name = 'my_swarm_1'          
gbest_x = np.zeros(2) 
gbest_obj = np.inf
s=swarm(swarm_name,gbest_x,gbest_obj)
for i in range(n_particals):
    name= "P"+str(i)
    position = (ub - lb)*np.random.rand() + lb
    velocity =  np.zeros(2)
    pbest_x = np.zeros(2) 
    pbest_obj = np.inf
    part = particle(name,position,velocity,pbest_x,pbest_obj)
    s.add_particles(part)

s.display_particles()
# Out:
# particles in my_swarm_1: gbest_x= [0. 0.], gbest_obj= inf
#  partical: P0, position: [4.92614631 4.92614631], velocity: [0. 0.], pbest_x: [0. 0.], pbest_obj: inf
#  partical: P1, position: [5.03245879 5.03245879], velocity: [0. 0.], pbest_x: [0. 0.], pbest_obj: inf
#  partical: P2, position: [6.08290796 6.08290796], velocity: [0. 0.], pbest_x: [0. 0.], pbest_obj: inf
#  partical: P3, position: [4.75655962 4.75655962], velocity: [0. 0.], pbest_x: [0. 0.], pbest_obj: inf
#  partical: P4, position: [3.23509169 3.23509169], velocity: [0. 0.], pbest_x: [0. 0.], pbest_obj: inf

# %%
for t in range(1,iter+1):

    for k in range(n_particals):
        current_x = s.particles[k].position
        current_obj =  objective_function(current_x)
        print(current_x,current_obj)

        if current_obj < s.particles[k].pbest_obj:
            s.particles[k].pbest_x = current_x
            s.particles[k].pbest_obj = current_obj

        if current_obj < s.gbest_obj:
            s.gbest_x = current_x
            s.gbest_obj = current_obj

    w = w_max - t*((w_max-w_min)/iter)
    # print('-'*10, 'iter',t,'w',w,'-'*10)

    for k in range(n_particals):
        
        s.particles[k].velocity = (w*s.particles[k].velocity) + ( c1*np.random.rand()*(s.particles[k].pbest_x - s.particles[k].position) ) + ( c1*np.random.rand()*( s.gbest_x - s.particles[k].position) )

        s.particles[k].velocity[s.particles[k].velocity > v_max] = v_max[ s.particles[k].velocity > v_max ]
        s.particles[k].velocity[s.particles[k].velocity < v_min] = v_min[ s.particles[k].velocity < v_min ]

        
        s.particles[k].position = s.particles[k].position + s.particles[k].velocity 

        s.particles[k].position[s.particles[k].position > ub] = ub[ s.particles[k].position > ub ]
        s.particles[k].position[s.particles[k].position < lb] = lb[ s.particles[k].position < lb ]

        
        # print('s.particles[k].position',s.particles[k].position,"s.particles[k].velocity",s.particles[k].velocity)
        # print()

print("result",s.gbest_x,s.gbest_obj)
# Out:
# [4.92614631 4.92614631] 24.26691748066031
# [5.03245879 5.03245879] 25.3256414466213
# [6.08290796 6.08290796] 37.001769201672914
# [4.75655962 4.75655962] 22.624859444271284
# [3.23509169 3.23509169] 10.465818261619026
# [3.92614631 3.92614631] 15.414624857994193
# [4.62522984 4.62522984] 21.392751042896823
# [5.08290796 5.08290796] 25.835953289589924
# [4.47503153 4.47503153] 20.025907200635526
# [3.23509169 3.23509169] 10.465818261619026
# [2.92614631 2.92614631] 8.562332235328073
# [3.62522984 3.62522984] 13.142291369367765
# [4.08290796 4.08290796] 16.670137377506933
# [3.47503153 3.47503153] 12.07584413926316
# [3.23509169 3.23509169] 10.465818261619026
# [2.23614631 2.23614631] 5.0003503256884505
# [2.62522984 2.62522984] 6.89183169583871
# [3.08290796 3.08290796] 9.504321465423946
# [2.47503153 2.47503153] 6.125781077890792
# [2.87037969 2.87037969] 8.239079538749493
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2.08290796 2.08290796] 4.338505553340957
# [2. 2.] 4.0
# [2.26380549 2.26380549] 5.124815301361882
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# [2. 2.] 4.0
# result [2. 2.] 4.0
