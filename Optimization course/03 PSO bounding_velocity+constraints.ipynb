# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class particle:
    def __init__(self, partical_name, x, v, pbest_x, pbest_obj):
        self.name = partical_name
        self.position = x
        self.velocity = v
        self.pbest_x  = pbest_x
        self.pbest_obj = pbest_obj

    def __str__(self):
        return f" partical: {self.name}, position: {self.position}, velocity: {self.velocity}, pbest_x: {self.pbest_x}, pbest_obj: {self.pbest_obj}"

class swarm:
    def __init__(self, swarm_name, gbest_x, gbest_obj):
        self.swarm_name = swarm_name
        self.gbest_x = gbest_x
        self.gbest_obj = gbest_obj
        self.particles = []

    def add_particles(self, particle):
        self.particles.append(particle)

    def display_particles(self):
        print(f"particles in {self.swarm_name}: gbest_x= {self.gbest_x}, gbest_obj= {self.gbest_obj}")
        for particle in self.particles:
            print(particle)

# %%
# def objective_function(x):
#     length = x[0]
#     width = x[1]

#     penalty = 0
#     if (13-(length+width))<=0:
#         print('inside1')
#         penalty = np.inf
#     elif ((length<2) or (width<2)):
#         print('inside2')
#         penalty=np.inf
#     elif (((length/width)<1) or ((length/width)>1)):
#         print('inside3')
#         penalty = np.inf
#     print(penalty)
    
#     weight = 1*(width+length)
#     return weight +penalty

def objective_function(x):
    #sphere function
    penalty = 0

    if (x[1]>=3.2 and x[1]<=6.4):
        print("inside 1")
        penalty = np.inf
    elif x[0]==x[1]:
        print("inside 2")
        penalty = np.inf
    print("penalty",penalty)
    

    
    z = np.sum(np.square(x))
    return z + penalty


nVar = 2
ub = np.array([10,10])
lb = np.array([-10,-10])

w_max = 0.9
w_min = 0.2
c1 =2
c2 =2
n_particals = 10

iter = 20

v_max = ( ub - lb ) *(0.2)
v_min = -v_max


##################
swarm_name = 'my_swarm_1'          
gbest_x = np.zeros(2) 
gbest_obj = np.inf
s=swarm(swarm_name,gbest_x,gbest_obj)
for i in range(n_particals):
    name= "P"+str(i)
    position = (ub - lb)*np.random.rand(nVar) + lb
    velocity =  np.zeros(2)
    pbest_x = np.zeros(2) 
    pbest_obj = np.inf
    part = particle(name,position,velocity,pbest_x,pbest_obj)
    s.add_particles(part)

s.display_particles()
# Out:
# particles in my_swarm_1: gbest_x= [0. 0.], gbest_obj= inf
#  partical: P0, position: [ 8.61228163 -6.42516642], velocity: [0. 0.], pbest_x: [0. 0.], pbest_obj: inf
#  partical: P1, position: [ 3.69559056 -9.62762606], velocity: [0. 0.], pbest_x: [0. 0.], pbest_obj: inf
#  partical: P2, position: [-7.72913161 -7.66729472], velocity: [0. 0.], pbest_x: [0. 0.], pbest_obj: inf
#  partical: P3, position: [-0.36737862  6.78685254], velocity: [0. 0.], pbest_x: [0. 0.], pbest_obj: inf
#  partical: P4, position: [-7.21848439  4.17318365], velocity: [0. 0.], pbest_x: [0. 0.], pbest_obj: inf
#  partical: P5, position: [0.77207448 2.41385866], velocity: [0. 0.], pbest_x: [0. 0.], pbest_obj: inf
#  partical: P6, position: [-8.45564089  0.23468102], velocity: [0. 0.], pbest_x: [0. 0.], pbest_obj: inf
#  partical: P7, position: [-6.33376888 -5.15332307], velocity: [0. 0.], pbest_x: [0. 0.], pbest_obj: inf
#  partical: P8, position: [5.74915956 6.8599965 ], velocity: [0. 0.], pbest_x: [0. 0.], pbest_obj: inf
#  partical: P9, position: [-5.5644008  -0.36344231], velocity: [0. 0.], pbest_x: [0. 0.], pbest_obj: inf

# %%
for t in range(1,iter+1):
    print('-'*20,f"iter_{t}",'-'*20)

    for k in range(n_particals):
        current_x = s.particles[k].position
        current_obj =  objective_function(current_x)
        print('p'+str(k),current_x,current_obj)

        if current_obj < s.particles[k].pbest_obj:
            s.particles[k].pbest_x = current_x
            s.particles[k].pbest_obj = current_obj

        if current_obj < s.gbest_obj:
            s.gbest_x = current_x
            s.gbest_obj = current_obj

    w = w_max - t*((w_max-w_min)/iter)
    # print('-'*10, 'iter',t,'w',w,'-'*10)

    for k in range(n_particals):
        
        s.particles[k].velocity = (w*s.particles[k].velocity) + ( c1*np.random.rand()*(s.particles[k].pbest_x - s.particles[k].position) ) + ( c1*np.random.rand()*( s.gbest_x - s.particles[k].position) )

        s.particles[k].velocity[s.particles[k].velocity > v_max] = v_max[ s.particles[k].velocity > v_max ]
        s.particles[k].velocity[s.particles[k].velocity < v_min] = v_min[ s.particles[k].velocity < v_min ]

        
        s.particles[k].position = s.particles[k].position + s.particles[k].velocity 

        s.particles[k].position[s.particles[k].position > ub] = ub[ s.particles[k].position > ub ]
        s.particles[k].position[s.particles[k].position < lb] = lb[ s.particles[k].position < lb ]

        
        # print('s.particles[k].position',s.particles[k].position,"s.particles[k].velocity",s.particles[k].velocity)
        # print()

print("result_gbest",s.gbest_x,s.gbest_obj)
# Out:
# -------------------- iter_1 --------------------
# penalty 0
# p0 [ 8.61228163 -6.42516642] 115.45415842613127
# penalty 0
# p1 [ 3.69559056 -9.62762606] 106.3485730809957
# penalty 0
# p2 [-7.72913161 -7.66729472] 118.52688367388227
# penalty 0
# p3 [-0.36737862  6.78685254] 46.19633442687161
# inside 1
# penalty inf
# p4 [-7.21848439  4.17318365] inf
# penalty 0
# p5 [0.77207448 2.41385866] 6.4228126518372015
# penalty 0
# p6 [-8.45564089  0.23468102] 71.5529380367812
# penalty 0
# p7 [-6.33376888 -5.15332307] 66.67336690955015
# penalty 0
# p8 [5.74915956 6.8599965 ] 80.11238755078428
# penalty 0
# p9 [-5.5644008  -0.36344231] 31.094646619872464
# -------------------- iter_2 --------------------
# penalty 0
# p0 [ 7.15428942 -4.78143055] 74.04593522178558
# penalty 0
# p1 [ 3.01037002 -6.8053147 ] 55.37463578580953
# penalty 0
# p2 [-3.72913161 -3.66729472] 27.355473082798852
# penalty 0
# p3 [1.90268747 2.78685254] 11.386766692800192
# penalty 0
# p4 [-3.21848439  0.17318365] 10.388634363132388
# penalty 0
# p5 [0.77207448 2.41385866] 6.4228126518372015
# penalty 0
# p6 [-4.45564089  2.93013083] 28.438402427605467
# penalty 0
# p7 [-2.33376888 -1.15332307] 6.776631299803252
# inside 1
# penalty inf
# p8 [3.13434348 4.52412469] inf
# inside 1
# penalty inf
# p9 [-1.5644008   3.63655769] inf
# -------------------- iter_3 --------------------
# penalty 0
# p0 [ 3.15428942 -0.78143055] 10.56017544851575
# penalty 0
# p1 [ 1.85425096 -2.8053147 ] 11.308037151264731
# penalty 0
# p2 [0.27086839 0.33270528] 0.18406249171543376
# penalty 0
# p3 [ 1.92635406 -1.14693019] 5.026288832388854
# penalty 0
# p4 [0.78151561 1.30896375] 2.324152744495988
# penalty 0
# p5 [0.77207448 2.41385866] 6.4228126518372015
# inside 1
# penalty inf
# p6 [-0.45564089  4.45510158] inf
# penalty 0
# p7 [1.66623112 2.84667693] 10.879895690056355
# penalty 0
# p8 [-0.86565652  0.52412469] 1.0240679087804962
# inside 1
# penalty inf
# p9 [2.4355992  3.96069128] inf
# -------------------- iter_4 --------------------
# penalty 0
# p9 [-0.00183695 -0.00684137] 5.017869090509734e-05
# -------------------- iter_17 --------------------
# penalty 0
# p0 [-0.18859022 -1.24320821] 1.5811329250176458
# penalty 0
# p1 [-0.57620426 -0.15981413] 0.35755190325428854
# penalty 0
# p2 [0.1225299  0.09244206] 0.023559109569532964
# penalty 0
# p3 [0.01801582 0.45142473] 0.2041088584073556
# penalty 0
# p4 [0.10059959 0.04625642] 0.012259933575937895
# penalty 0
# p5 [-0.11769059 -0.05604286] 0.016991877606968138
# penalty 0
# p6 [ 0.04260506 -0.08240767] 0.008606215533216397
# penalty 0
# p7 [-0.05539008 -0.05479832] 0.006070916892077295
# penalty 0
# p8 [-0.20233398 -0.13592443] 0.0594144903279085
# penalty 0
# p9 [-0.06040641  0.02837844] 0.004454270201245784
# -------------------- iter_18 --------------------
# penalty 0
# p0 [0.1864597 0.5899582] 0.3828178954011052
# penalty 0
# p1 [0.44475731 0.1255435 ] 0.21357023443430725
# penalty 0
# p2 [0.03654166 0.02393705] 0.0019082755152520859
# penalty 0
# p3 [-0.01419916 -0.46057946] 0.21233505421721166
# penalty 0
# p4 [-0.17782488 -0.08822895] 0.03940603524154268
# penalty 0
# p5 [0.06990271 0.01820081] 0.005217657837621369
# penalty 0
# p6 [ 0.01731873 -0.02840897] 0.0011070083341406778
# penalty 0
# p7 [0.048097   0.04537387] 0.004372109101583345
# penalty 0
# p8 [-0.28000563 -0.15921758] 0.10375338819967116
# penalty 0
# p9 [-0.00198522 -0.00675221] 4.95333804541069e-05
# -------------------- iter_19 --------------------
# penalty 0
# p0 [-0.20178296 -1.15569233] 1.3763411211772456
# penalty 0
# p1 [-0.26604003 -0.0796992 ] 0.07712925708479311
# penalty 0
# p2 [0.01084809 0.00346781] 0.00012970684344256513
# penalty 0
# p3 [-0.00779236 -0.24363482] 0.059418647384680966
# penalty 0
# p4 [-0.11909234 -0.06090926] 0.017892923915672737
# penalty 0
# p5 [0.04332604 0.01144039] 0.002008028697165797
# penalty 0
# p6 [-0.01692316  0.01692661] 0.0005729034005974851
# penalty 0
# p7 [-0.00938601 -0.01649033] 0.00036002838737248996
# penalty 0
# p8 [-0.01180604 -0.0208506 ] 0.0005741303665208459
# penalty 0
# p9 [ 0.0137885  -0.01623748] 0.0004537784274624278
# -------------------- iter_20 --------------------
# penalty 0
# p0 [0.46070433 1.93251593] 3.946866301829195
# penalty 0
# p1 [-0.38689771 -0.11517377] 0.16295483411236428
# penalty 0
# p2 [-0.01170973 -0.0144983 ] 0.0003473185524317749
# penalty 0
# p3 [-0.00201987 -0.01859938] 0.00035001678437448705
# penalty 0
# p4 [-0.0036642  -0.00647383] 5.533678001094449e-05
# penalty 0
# p5 [0.02905874 0.00663092] 0.0008883794128325044
# penalty 0
# p6 [-0.00488948 -0.00425009] 4.197031503370274e-05
# penalty 0
# p7 [-0.01799938 -0.02458729] 0.0009285123495745593
# penalty 0
# p8 [0.06851824 0.0364971 ] 0.00602678784261937
# penalty 0
# p9 [-0.02170877  0.00510823] 0.0004973647332886993
# result_gbest [-0.00488948 -0.00425009] 4.197031503370274e-05
